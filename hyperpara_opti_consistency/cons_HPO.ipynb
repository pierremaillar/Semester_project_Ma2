# %% [markdown]
# # Project 2 :

# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from python_modules.create_batch import *
from python_modules.datatreatment import *
from python_modules.neuralnet import *
from python_modules.visualisations import *
from python_modules.nn_hyperpara_opti import *
from python_modules.nn_hyperpara_opti_consistency import *
torch.cuda.is_available()
# Out:
# C:\Users\pierr\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# True

# %%
from job_HPO_cons_EUK import *
# Out:
# number of Opisthokonta :
# {25989}
# ---------
# number of Viridiplantae :
# {6861}
# ---------
# number of Sar :
# {2241}
# ---------
# number of Others :
# {1286}
# ---------
# shape of dataframe : (36377, 12834)
# C:\Users\pierr\Desktop\Semester_project_Ma2\hyperpara_opti_consistency\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# time: 304.508029460907
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9914730196912872, Std Validation F1 Score: 0.0009280140271534718, Mean Std of Scores: 0.242219481188447
#
# time: 682.1257927417755
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9918065190774189, Std Validation F1 Score: 0.0005078229327461484, Mean Std of Scores: 0.22383959340920467
#
# time: 1143.7239682674408
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.991883615816304, Std Validation F1 Score: 0.000619410080560521, Mean Std of Scores: 0.17629462311663033
#
# time: 1442.7919471263885
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9917645882518805, Std Validation F1 Score: 0.0009377999811566879, Mean Std of Scores: 0.2822218949633902
#
# time: 1816.3419082164764
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9915997735823974, Std Validation F1 Score: 0.0007603008166242987, Mean Std of Scores: 0.3652043552095569
#
# time: 2260.47084236145
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9918781611069709, Std Validation F1 Score: 0.0008180142634005523, Mean Std of Scores: 0.19770201489621245
#
# time: 2565.63658285141
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9917928850343816, Std Validation F1 Score: 0.002007593023866538, Mean Std of Scores: 0.3271919106665528
#
# time: 2940.6285371780396
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9916505984190017, Std Validation F1 Score: 0.0015967031392910313, Mean Std of Scores: 0.3415508719001843
#
# time: 3382.098748922348
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9910551268778259, Std Validation F1 Score: 0.0012451678731242848, Mean Std of Scores: 0.1958757546899331
#
# time: 3721.3357088565826
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9919228675607582, Std Validation F1 Score: 0.0011225378687789408, Mean Std of Scores: 0.199388224088747
#
# time: 4143.948557138443
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9916043613463962, Std Validation F1 Score: 0.0006260562924481637, Mean Std of Scores: 0.22227467566966885
#
# time: 4651.176446676254
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9916796096054159, Std Validation F1 Score: 0.00047394451263378906, Mean Std of Scores: 0.29731690636596614
#
# time: 4998.414016962051
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9909752945817085, Std Validation F1 Score: 0.0015767835615511767, Mean Std of Scores: 0.15789827454081892
#
# time: 5424.264145851135
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9904363051273284, Std Validation F1 Score: 0.0012244217855357923, Mean Std of Scores: 0.39138175566885636
#
# time: 5933.135689973831
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9917216687186622, Std Validation F1 Score: 0.0004555984385359887, Mean Std of Scores: 0.1903631183910281
#
# time: 6273.130655050278
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9881576882725148, Std Validation F1 Score: 0.008724011222972393, Mean Std of Scores: 0.23717461945028703
#
# time: 6698.226328611374
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9885633691765476, Std Validation F1 Score: 0.0050650008084775, Mean Std of Scores: 0.15343920395804356
#
# time: 7204.794923067093
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9891802303228228, Std Validation F1 Score: 0.0016841317014276377, Mean Std of Scores: 0.21686239869214646
#
# time: 7581.7917857170105
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 4, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 3, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9917221694477499, Std Validation F1 Score: 0.000601298455522779, Mean Std of Scores: 0.20513488990313916
#
# time: 28256.107141971588
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 3, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9916360179785211, Std Validation F1 Score: 0.0007297630393144754, Mean Std of Scores: 0.19697915867159338
#
# time: 28764.291487455368
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 3, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9916132083900092, Std Validation F1 Score: 0.0006388055695504057, Mean Std of Scores: 0.19985637980257212
#
# time: 29110.646692752838
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9914372473740338, Std Validation F1 Score: 0.000910992458094692, Mean Std of Scores: 0.17849274296490428
#
# time: 29543.251737594604
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9915021880237086, Std Validation F1 Score: 0.0007633742220675414, Mean Std of Scores: 0.1885942047211159
#
# time: 30069.097591876984
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9914622462253918, Std Validation F1 Score: 0.0007488103384991296, Mean Std of Scores: 0.1815048226073559
#
# time: 30461.21886587143
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9911720482998218, Std Validation F1 Score: 0.0006690880602036973, Mean Std of Scores: 0.2191413196312936
#
# time: 30954.13444495201
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9914875098430248, Std Validation F1 Score: 0.0007356692592781004, Mean Std of Scores: 0.21194585179693826
#
# time: 31542.108382225037
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9914913047291207, Std Validation F1 Score: 0.0008854329905331329, Mean Std of Scores: 0.239508253405418
#
# time: 31939.482177734375
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9910553025844338, Std Validation F1 Score: 0.0007395370266203705, Mean Std of Scores: 0.24677566338367135
#
# time: 32429.8679087162
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9917374965626045, Std Validation F1 Score: 0.000783216550199903, Mean Std of Scores: 0.2193027528725544
#
# time: 33029.591713905334
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.5, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9917104264935346, Std Validation F1 Score: 0.0006751849389290366, Mean Std of Scores: 0.23240076872265084
#
# time: 33427.28552389145
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 6}, Mean Validation F1 Score: 0.9908429651293221, Std Validation F1 Score: 0.0014274458231191467, Mean Std of Scores: 0.30681776752681056
#
# time: 33920.92033624649
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}, Mean Validation F1 Score: 0.9908697792824744, Std Validation F1 Score: 0.0008407178054951575, Mean Std of Scores: 0.4162291060820828
#
# time: 34519.159709215164
#
# Hyperparameters: {'layer_dim': 96, 'number_hidden_layer': 4, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 10}, Mean Validation F1 Score: 0.9908544885184549, Std Validation F1 Score: 0.0006520017946529751, Mean Std of Scores: 0.31144005919708057
#
#
# Best Hyperparameters:
# {'layer_dim': 32, 'number_hidden_layer': 3, 'dropout_prob': 0.7, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 8}
# Best Mean Validation F1 Score: 0.9885633691765476
# Std Validation F1 Score: 0.0050650008084775
# Best Mean Std of scores: 0.15343920395804356
#
#  stored f1 scores: [0.9914730196912872, 0.9918065190774189, 0.991883615816304, 0.9917645882518805, 0.9915997735823974, 0.9918781611069709, 0.9917928850343816, 0.9916505984190017, 0.9910551268778259, 0.9919228675607582, 0.9916043613463962, 0.9916796096054159, 0.9909752945817085, 0.9904363051273284, 0.9917216687186622, 0.9881576882725148, 0.9885633691765476, 0.9891802303228228, 0.9914871104517518, 0.9917766083890883, 0.9917709529357993, 0.9901242909878222, 0.9891341023574488, 0.9915525059104046, 0.9857229571740524, 0.9732345259571178, 0.982314340336118, 0.991519755862367, 0.9916652193489929, 0.9915173779482612, 0.9914216160104813, 0.9919951639178574, 0.9916792417391449, 0.9914801
# number of Cyanobacteriota/Melainabacteriagroup :
# {2368}
# ---------
# number of Chloroflexota :
# {1351}
# ---------
# number of Alveolata :
# {1167}
# ---------
# number of Planctomycetota :
# {1160}
# ---------
# number of Epsilonproteobacteria :
# {1055}
# ---------
# number of Stramenopiles :
# {1006}
# ---------
# number of Deltaproteobacteria :
# {924}
# ---------
# number of Myxococcia :
# {866}
# ---------
# number of Stenosarchaeagroup :
# {753}
# ---------
# number of Verrucomicrobiota :
# {648}
# ---------
# number of  :
# {546}
# ---------
# number of unclassifiedAcidobacteriota :
# {523}
# ---------
# number of Euglenozoa :
# {426}
# ---------
# number of Spirochaetia :
# {387}
# ---------
# number of Mycoplasmatota :
# {357}
# ---------
# number of Chlorophyta :
# {301}
# ---------
# number of unclassifiedEuryarchaeota :
# {301}
# ---------
# number of unclassifiedPseudomonadota :
# {249}
# ---------
# number of Nitrososphaerota :
# {246}
# ---------
# number of Evosea :
# {223}
# ---------
# shape of dataframe : (93204, 12906)
# C:\Users\pierr\Desktop\Semester_project_Ma2\hyperpara_opti_consistency\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# time: 614.6525135040283
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 5}, Mean Validation F1 Score: 0.9758788717195608, Std Validation F1 Score: 0.0035277963979308403, Mean Std of Scores: 0.27159818953059806
#
# time: 1473.4100801944733
#
# Hyperparameters: {'layer_dim': 32, 'number_hidden_layer': 2, 'dropout_prob': 0.3, 'l2_regu': 1e-05, 'weight_decay': 0.0001, 'learning_rate': 0.0001, 'batch_size': 64, 'num_epochs': 7}, Mean Validation F1 Score: 0.9761744164460063, Std Validation F1 Score: 0.0021449834475654244, Mean Std of Scores: 0.25105593163389495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from job_HPO_cons_task30 import *
#
# File ~\Desktop\Semester_project_Ma2\hyperpara_opti_consistency\job_HPO_cons_task30.py:41
#      38 train, train_label, test, test_label, val, val_label=split_dataset(level3, 0.8, 0.1, 0.1)
#      40 output_dim = 30
# ---> 41 best_params_nn, mean_values, std_values = optimize_hyperparameters_nn_consistency(train, train_label, val, val_label, output_dim,columns_info,param_grid,nbr_training,positions_to_keep)
#      46 print("Job finished")
#
# File ~\Desktop\Semester_project_Ma2\hyperpara_opti_consistency\python_modules\nn_hyperpara_opti_consistency.py:155, in optimize_hyperparameters_nn_consistency(train_inputs, train_labels, val_inputs, val_labels, output_dim, columns_info, param_grid, nbr_training, pos)
#     152 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     154 # Perform cross-validation using batched training
# --> 155 mean_f1, std_f1, mean_scores, std_scores = cross_val_pos_consistency(dict(zip(param_grid.keys(), hyperparams)), train_inputs,train_labels, val_inputs, val_labels,output_dim,columns_info,device,nbr_training, pos)
#     157 # Print the results for the current hyperparameter combination
#     158 print(f"time: {time.time()-start_time}\n")
#
# File ~\Desktop\Semester_project_Ma2\hyperpara_opti_consistency\python_modules\nn_hyperpara_opti_consistency.py:95, in cross_val_pos_consistency(hyperparam_dict, train_inputs, train_labels, val_inputs, val_labels, output_dim, columns_info, device, nbr_training, pos)
#      93         outputs = model(inputs)
#      94         loss = model.get_loss(outputs, labels)
# ---> 95         loss.backward()
#      96         optimizer.step()
#      97 # Generate predictions for the validation set
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:
