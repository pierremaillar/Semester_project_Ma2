# %% [markdown]
# # Project 2 :

# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from python_modules.create_batch import *
from python_modules.datatreatment import *
from python_modules.neuralnet import *
from python_modules.visualisations import *
from python_modules.nn_hyperpara_opti import *
from python_modules.nn_hyperpara_opti_consistency import *
torch.cuda.is_available()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True

# %%
from Job_scores_BEA import *
from Job_scores_EUK import *
from Job_scores_BAC import *
from Job_scores_task30 import *

# %%
# %run Job_scores_task30.py
# Out:
# number of Metazoa :
# {18059}
# ---------
# number of Gammaproteobacteria :
# {13237}
# ---------
# number of Bacillota :
# {8001}
# ---------
# number of Fungi :
# {7894}
# ---------
# number of Actinomycetota :
# {7118}
# ---------
# number of Streptophyta :
# {6556}
# ---------
# number of Alphaproteobacteria :
# {5340}
# ---------
# number of Betaproteobacteria :
# {4918}
# ---------
# number of Bacteroidetes/Chlorobigroup :
# {4674}
# ---------
# number of Bacteriacandidatephyla :
# {2550}
# ---------
# number of Cyanobacteriota/Melainabacteriagroup :
# {2368}
# ---------
# number of Chloroflexota :
# {1351}
# ---------
# number of Alveolata :
# {1167}
# ---------
# number of Planctomycetota :
# {1160}
# ---------
# number of Epsilonproteobacteria :
# {1055}
# ---------
# number of Stramenopiles :
# {1006}
# ---------
# number of Deltaproteobacteria :
# {924}
# ---------
# number of Myxococcia :
# {866}
# ---------
# number of Stenosarchaeagroup :
# {753}
# ---------
# ...

# %%
# %run Job_scores_EUK.py
# Out:
# number of Opisthokonta :
# {25989}
# ---------
# number of Viridiplantae :
# {6861}
# ---------
# number of Sar :
# {2241}
# ---------
# number of Others :
# {1286}
# ---------
# shape of dataframe : (36377, 12834)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/8], Training Loss: 0.5376
# Epoch [1/8], Validation Loss: 0.3407
# Epoch [1/8], Validation Accuracy: 89.8543%
# Epoch [2/8], Training Loss: 0.4401
# Epoch [2/8], Validation Loss: 0.2002
# Epoch [2/8], Validation Accuracy: 90.4042%
# Epoch [3/8], Training Loss: 0.2145
# Epoch [3/8], Validation Loss: 0.1510
# ...

# %%
# %run Job_scores_BAC.py
# Out:
# number of Pseudomonadota :
# {23889}
# ---------
# number of Terrabacteriagroup :
# {19458}
# ---------
# number of FCBgroup :
# {5211}
# ---------
# number of Bacteriaincertaesedis :
# {2557}
# ---------
# number of PVCgroup :
# {2126}
# ---------
# number of Campylobacterota :
# {1082}
# ---------
# shape of dataframe : (54323, 11450)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/10], Training Loss: 0.1566
# Epoch [1/10], Validation Loss: 0.1016
# Epoch [1/10], Validation Accuracy: 98.1038%
# Epoch [2/10], Training Loss: 0.0148
# Epoch [2/10], Validation Loss: 0.0594
# ...

# %%
from Job_scores_BEA import *
# Out:
# number of Bacteria :
# {59810}
# ---------
# number of Eukaryota :
# {36377}
# ---------
# number of Archaea :
# {2207}
# ---------
# shape of dataframe : (98394, 12927)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/10], Training Loss: 0.0118
# Epoch [1/10], Validation Loss: 0.0166
# Epoch [1/10], Validation Accuracy: 99.7154%
# Epoch [2/10], Training Loss: 0.0016
# Epoch [2/10], Validation Loss: 0.0149
# Epoch [2/10], Validation Accuracy: 99.7053%
# Epoch [3/10], Training Loss: 0.1461
# Epoch [3/10], Validation Loss: 0.0118
# Epoch [3/10], Validation Accuracy: 99.8171%
# ...

# %%
# %run Job_scores_BEA.py
# Out:
# number of Bacteria :
# {59810}
# ---------
# number of Eukaryota :
# {36377}
# ---------
# number of Archaea :
# {2207}
# ---------
# shape of dataframe : (98394, 12927)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/10], Training Loss: 0.0060
# Epoch [1/10], Validation Loss: 0.0227
# Epoch [1/10], Validation Accuracy: 99.5630%
# Epoch [2/10], Training Loss: 0.0030
# Epoch [2/10], Validation Loss: 0.0159
# Epoch [2/10], Validation Accuracy: 99.7662%
# Epoch [3/10], Training Loss: 0.0040
# Epoch [3/10], Validation Loss: 0.0142
# Epoch [3/10], Validation Accuracy: 99.7764%
# ...
