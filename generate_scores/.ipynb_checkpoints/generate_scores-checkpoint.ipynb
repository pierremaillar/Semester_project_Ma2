# %% [markdown]
# # Project 2 :

# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from python_modules.create_batch import *
from python_modules.datatreatment import *
from python_modules.neuralnet import *
from python_modules.visualisations import *
from python_modules.nn_hyperpara_opti import *
from python_modules.nn_hyperpara_opti_consistency import *
torch.cuda.is_available()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True

# %%
#from Job_scores_BEA import *
from Job_scores_EUK import *
from Job_scores_BAC import *
from Job_scores_task30 import *
# Out:
# C:\Users\pierr\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# number of Opisthokonta :
# {25989}
# ---------
# number of Viridiplantae :
# {6861}
# ---------
# number of Sar :
# {2241}
# ---------
# number of Others :
# {1286}
# ---------
# shape of dataframe : (36377, 12834)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/5], Training Loss: 0.3292
# Epoch [1/5], Validation Loss: 0.2406
# Epoch [1/5], Validation Accuracy: 89.8268%
# Epoch [2/5], Training Loss: 0.1976
# Epoch [2/5], Validation Loss: 0.1341
# Epoch [2/5], Validation Accuracy: 95.3533%
# Epoch [3/5], Training Loss: 0.2120
# Epoch [3/5], Validation Loss: 0.1003
# Epoch [3/5], Validation Accuracy: 95.8482%
# Epoch [4/5], Training Loss: 0.2026
# Epoch [4/5], Validation Loss: 0.0846
# Epoch [4/5], Validation Accuracy: 96.0957%
# Epoch [5/5], Training Loss: 0.0709
# Epoch [5/5], Validation Loss: 0.0681
# Epoch [5/5], Validation Accuracy: 96.8930%
# Got to iteration 1 in 11.997040033340454 seconds
# Epoch [1/5], Training Loss: 0.2357
# Epoch [1/5], Validation Loss: 0.2490
# Epoch [1/5], Validation Accuracy: 89.9918%
# Epoch [2/5], Training Loss: 0.2226
# Epoch [2/5], Validation Loss: 0.1260
# Epoch [2/5], Validation Accuracy: 95.6283%
# Epoch [3/5], Training Loss: 0.0869
# Epoch [3/5], Validation Loss: 0.0940
# Epoch [3/5], Validation Accuracy: 95.8757%
# Epoch [4/5], Training Loss: 0.0999
# Epoch [4/5], Validation Loss: 0.0732
# Epoch [4/5], Validation Accuracy: 97.3055%
# Epoch [5/5], Training Loss: 0.0591
# Epoch [5/5], Validation Loss: 0.0605
# Epoch [5/5], Validation Accuracy: 98.3778%
# Got to iteration 2 in 22.678165435791016 seconds
# Epoch [1/5], Training Loss: 0.3780
# Epoch [1/5], Validation Loss: 0.2207
# Epoch [1/5], Validation Accuracy: 89.9643%
# Epoch [2/5], Training Loss: 0.2738
# Epoch [2/5], Validation Loss: 0.1298
# Epoch [2/5], Validation Accuracy: 95.3533%
# Epoch [3/5], Training Loss: 0.0842
# Epoch [3/5], Validation Loss: 0.1024
# Epoch [3/5], Validation Accuracy: 95.6833%
# Epoch [4/5], Training Loss: 0.0889
# Epoch [4/5], Validation Loss: 0.0869
# Epoch [4/5], Validation Accuracy: 96.0407%
# Epoch [5/5], Training Loss: 0.4644
# Epoch [5/5], Validation Loss: 0.0752
# Epoch [5/5], Validation Accuracy: 96.9205%
# Got to iteration 3 in 33.39825677871704 seconds
# consistency score: 0.1078360517466306
# output/pdb_files/5nro_EUK.pdb has been created with 5097 values modified
# Job finished
# number of Pseudomonadota :
# {23889}
# ---------
# number of Terrabacteriagroup :
# {19458}
# ---------
# number of FCBgroup :
# {5211}
# ---------
# number of Bacteriaincertaesedis :
# {2557}
# ---------
# number of PVCgroup :
# {2126}
# ---------
# number of Campylobacterota :
# {1082}
# ---------
# shape of dataframe : (54323, 11450)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/3], Training Loss: 0.2896
# Epoch [1/3], Validation Loss: 0.1584
# Epoch [1/3], Validation Accuracy: 95.6001%
# Epoch [2/3], Training Loss: 0.1580
# Epoch [2/3], Validation Loss: 0.0911
# Epoch [2/3], Validation Accuracy: 98.3063%
# Epoch [3/3], Training Loss: 0.0507
# Epoch [3/3], Validation Loss: 0.0726
# Epoch [3/3], Validation Accuracy: 98.6929%
# Got to iteration 1 in 10.968214511871338 seconds
# Epoch [1/3], Training Loss: 0.2601
# Epoch [1/3], Validation Loss: 0.1755
# Epoch [1/3], Validation Accuracy: 96.1340%
# Epoch [2/3], Training Loss: 0.1447
# Epoch [2/3], Validation Loss: 0.0972
# Epoch [2/3], Validation Accuracy: 97.9381%
# Epoch [3/3], Training Loss: 0.0319
# Epoch [3/3], Validation Loss: 0.0789
# Epoch [3/3], Validation Accuracy: 98.4720%
# Got to iteration 2 in 20.74419927597046 seconds
# Epoch [1/3], Training Loss: 0.3238
# Epoch [1/3], Validation Loss: 0.1674
# Epoch [1/3], Validation Accuracy: 95.9315%
# Epoch [2/3], Training Loss: 0.1751
# Epoch [2/3], Validation Loss: 0.0929
# Epoch [2/3], Validation Accuracy: 98.2143%
# Epoch [3/3], Training Loss: 0.0221
# Epoch [3/3], Validation Loss: 0.0730
# Epoch [3/3], Validation Accuracy: 98.5825%
# Got to iteration 3 in 29.77235221862793 seconds
# consistency score: 0.3666091151625011
# output/pdb_files/5nro_BAC.pdb has been created with 5097 values modified
# Job finished
# number of Metazoa :
# {18059}
# ---------
# number of Gammaproteobacteria :
# {13237}
# ---------
# number of Bacillota :
# {8001}
# ---------
# number of Fungi :
# {7894}
# ---------
# number of Actinomycetota :
# {7118}
# ---------
# number of Streptophyta :
# {6556}
# ---------
# number of Alphaproteobacteria :
# {5340}
# ---------
# number of Betaproteobacteria :
# {4918}
# ---------
# number of Bacteroidetes/Chlorobigroup :
# {4674}
# ---------
# number of Bacteriacandidatephyla :
# {2550}
# ---------
# number of Cyanobacteriota/Melainabacteriagroup :
# {2368}
# ---------
# number of Chloroflexota :
# {1351}
# ---------
# number of Alveolata :
# {1167}
# ---------
# number of Planctomycetota :
# {1160}
# ---------
# number of Epsilonproteobacteria :
# {1055}
# ---------
# number of Stramenopiles :
# {1006}
# ---------
# number of Deltaproteobacteria :
# {924}
# ---------
# number of Myxococcia :
# {866}
# ---------
# number of Stenosarchaeagroup :
# {753}
# ---------
# number of Verrucomicrobiota :
# {648}
# ---------
# number of  :
# {546}
# ---------
# number of unclassifiedAcidobacteriota :
# {523}
# ---------
# number of Euglenozoa :
# {426}
# ---------
# number of Spirochaetia :
# {387}
# ---------
# number of Mycoplasmatota :
# {357}
# ---------
# number of Chlorophyta :
# {301}
# ---------
# number of unclassifiedEuryarchaeota :
# {301}
# ---------
# number of unclassifiedPseudomonadota :
# {249}
# ---------
# number of Nitrososphaerota :
# {246}
# ---------
# number of Evosea :
# {223}
# ---------
# shape of dataframe : (93204, 12906)
# C:\Users\pierr\Desktop\Semester_project_Ma2\generate_scores\python_modules\datatreatment.py:191: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.iloc[:, 0] = data.iloc[:, 0].replace(map_dict)
# Epoch [1/7], Training Loss: 2.8092
# Epoch [1/7], Validation Loss: 2.7826
# Epoch [1/7], Validation Accuracy: 33.3584%
# Epoch [2/7], Training Loss: 2.2232
# Epoch [2/7], Validation Loss: 2.0543
# Epoch [2/7], Validation Accuracy: 53.1867%
# Epoch [3/7], Training Loss: 1.7627
# Epoch [3/7], Validation Loss: 1.6238
# Epoch [3/7], Validation Accuracy: 61.2124%
# Epoch [4/7], Training Loss: 1.4638
# Epoch [4/7], Validation Loss: 1.3097
# Epoch [4/7], Validation Accuracy: 66.2768%
# Epoch [5/7], Training Loss: 1.4120
# Epoch [5/7], Validation Loss: 1.0788
# Epoch [5/7], Validation Accuracy: 74.0987%
# Epoch [6/7], Training Loss: 1.2392
# Epoch [6/7], Validation Loss: 0.9111
# Epoch [6/7], Validation Accuracy: 80.6223%
# Epoch [7/7], Training Loss: 1.1556
# Epoch [7/7], Validation Loss: 0.7953
# Epoch [7/7], Validation Accuracy: 82.9077%
# Got to iteration 1 in 10.301984071731567 seconds
# Epoch [1/7], Training Loss: 2.8105
# Epoch [1/7], Validation Loss: 2.7160
# Epoch [1/7], Validation Accuracy: 20.5687%
# Epoch [2/7], Training Loss: 2.2837
# Epoch [2/7], Validation Loss: 2.1779
# Epoch [2/7], Validation Accuracy: 46.7918%
# Epoch [3/7], Training Loss: 1.8876
# Epoch [3/7], Validation Loss: 1.7017
# Epoch [3/7], Validation Accuracy: 51.3948%
# Epoch [4/7], Training Loss: 1.6048
# Epoch [4/7], Validation Loss: 1.3388
# Epoch [4/7], Validation Accuracy: 67.3498%
# Epoch [5/7], Training Loss: 1.3341
# Epoch [5/7], Validation Loss: 1.0745
# Epoch [5/7], Validation Accuracy: 78.6373%
# Epoch [6/7], Training Loss: 1.1792
# Epoch [6/7], Validation Loss: 0.8905
# Epoch [6/7], Validation Accuracy: 82.4249%
# Epoch [7/7], Training Loss: 1.0490
# Epoch [7/7], Validation Loss: 0.7619
# Epoch [7/7], Validation Accuracy: 83.4657%
# Got to iteration 2 in 18.357560873031616 seconds
# Epoch [1/7], Training Loss: 2.7600
# Epoch [1/7], Validation Loss: 2.7297
# Epoch [1/7], Validation Accuracy: 19.7639%
# Epoch [2/7], Training Loss: 2.1928
# Epoch [2/7], Validation Loss: 2.1019
# Epoch [2/7], Validation Accuracy: 45.2146%
# Epoch [3/7], Training Loss: 1.8090
# Epoch [3/7], Validation Loss: 1.6390
# Epoch [3/7], Validation Accuracy: 55.2790%
# Epoch [4/7], Training Loss: 1.5708
# Epoch [4/7], Validation Loss: 1.2973
# Epoch [4/7], Validation Accuracy: 67.7146%
# Epoch [5/7], Training Loss: 1.3452
# Epoch [5/7], Validation Loss: 1.0577
# Epoch [5/7], Validation Accuracy: 77.0172%
# Epoch [6/7], Training Loss: 1.1991
# Epoch [6/7], Validation Loss: 0.8891
# Epoch [6/7], Validation Accuracy: 80.0429%
# Epoch [7/7], Training Loss: 1.0088
# Epoch [7/7], Validation Loss: 0.7735
# Epoch [7/7], Validation Accuracy: 82.4893%
# Got to iteration 3 in 26.63380265235901 seconds
# consistency score: 0.4222372330067619
# output/pdb_files/5nro_task30.pdb has been created with 5097 values modified
# Job finished
